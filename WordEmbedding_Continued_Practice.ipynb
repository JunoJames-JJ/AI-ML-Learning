# %% [markdown]
# <a href="https://colab.research.google.com/github/JunoJames-JJ/AI-ML-Learning/blob/main/WordEmbedding_Continued_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from gensim.models import Word2Vec
sentences = [
    ["the","cat","sat","on","the","mat"],
    ["the","dog","sat","on","the","log"],
]

w2v_sg = Word2Vec(
    sentences,
    vector_size=100,
    window=5,
    min_count=1,
    sg=1,
    negative=10,
    epochs=10,
    workers=1,
    seed=42
)


# --- use the vectors ---
print("vector for 'cat' (first 5 dims):", w2v_sg.wv["cat"][:5])
print("similarity(cat, dog):", w2v_sg.wv.similarity("cat", "dog"))
print("most similar to 'cat':", w2v_sg.wv.most_similar("cat", topn=3))
# Out:
# vector for 'cat' (first 5 dims): [ 0.00232568  0.00557993  0.00478086 -0.00730896  0.0065211 ]
# similarity(cat, dog): -0.14846532
# most similar to 'cat': [('on', 0.025957388803362846), ('sat', -0.008650765754282475), ('the', -0.01076418161392212)]

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 82.4 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %% [markdown]
# **word-similarity**

# %%
import gensim.downloader as api
wv = api.load("word2vec-google-news-300")
print(wv.most_similar("juno")[:5])
# Out:
# [('petewentz_@', 0.5449389219284058), ('alicia_keys', 0.543157160282135), ('hannah', 0.541007936000824), ('becky', 0.5405266880989075), ('bieber', 0.5398492813110352)]

# %% [markdown]
# GloVe has official Stanford releases while Word2Vec has widely used pretrained checkpoints (e.g., GoogleNews).

# %%
#Glove

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import gensim.downloader


# Load model
model = gensim.downloader.load("glove-wiki-gigaword-50")

# Pick some words to compare
words = ["tower", "skyscraper", "building", "lighthouse", "castle", "bridge", "sky", "mountain", "waterfalls", "trees", "leaves"]

vectors = [model[word] for word in words]

pca=PCA(n_components=2)
reduced=pca.fit_transform(vectors)


# Plot
plt.figure(figsize=(8, 6))
plt.scatter(reduced[:, 0], reduced[:, 1], color = "blue")

for i, word in enumerate(words):
    plt.text(reduced[i, 0] + 0.02, reduced[i, 1] + 0.02, word)

plt.title("Word Embeddings (2D PCA projection)")
plt.show()
